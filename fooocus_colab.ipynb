# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# Collecting pygit2==1.15.1
#   Downloading pygit2-1.15.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pygit2==1.15.1) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (3.0)
# Downloading pygit2-1.15.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 49.3 MB/s eta 0:00:00
# Installing collected packages: pygit2
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.19.1
#     Uninstalling pygit2-1.19.1:
#       Successfully uninstalled pygit2-1.19.1
# Successfully installed pygit2-1.15.1
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6735, done.
# remote: Total 6735 (delta 0), reused 0 (delta 0), pack-reused 6735 (from 1)
# Receiving objects: 100% (6735/6735), 33.36 MiB | 27.22 MiB/s, done.
# Resolving deltas: 100% (3850/3850), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# /content/Fooocus/build_launcher.py:9: SyntaxWarning: invalid escape sequence '\p'
#   .\python_embeded\python.exe -s Fooocus\entry_with_update.py {cmds} %*
# Python 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 2.97MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 1.78MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 41.9MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:02<00:00, 144MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_v8Rundiffusion.safetensors" to /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
#
# 100% 6.62G/6.62G [01:03<00:00, 112MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100% 47.3M/47.3M [00:00<00:00, 80.1MB/s]
# Total VRAM 15095 MB, total RAM 12976 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# /content/Fooocus/ldm_patched/unipc/uni_pc.py:56: SyntaxWarning: invalid escape sequence '\h'
#   The `alphas_cumprod` is the \hat{alpha_n} arrays in the notations of DDPM. Specifically, DDPMs assume that
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://1536a7d7e766b3a474.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_l.text_projection'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.68 seconds
# 2026-01-29 19:57:57.833323: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769716678.103397    1492 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769716678.177783    1492 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769716678.723496    1492 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769716678.723540    1492 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769716678.723546    1492 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769716678.723553    1492 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-29 19:57:58.772794: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 547
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://1536a7d7e766b3a474.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 5661696719680970456
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/clip_vision_vit_h.safetensors" to /content/Fooocus/models/clip_vision/clip_vision_vit_h.safetensors
#
# 100% 1.84G/1.84G [00:31<00:00, 63.2MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_ip_negative.safetensors" to /content/Fooocus/models/controlnet/fooocus_ip_negative.safetensors
#
# 100% 64.1k/64.1k [00:00<00:00, 878kB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/ip-adapter-plus_sdxl_vit-h.bin" to /content/Fooocus/models/controlnet/ip-adapter-plus_sdxl_vit-h.bin
#
# 100% 967M/967M [00:26<00:00, 38.8MB/s]
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Wildcards] processing: A cute simple line art drawing of a __test_list__, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast
# [Wildcards] Warning: test_list.txt missing or empty. Using "test_list" as a normal word.
# [Wildcards] A cute simple line art drawing of a test_list, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast
# [Wildcards] processing: A cute simple line art drawing of a __test_list__, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast
# [Wildcards] Warning: test_list.txt missing or empty. Using "test_list" as a normal word.
# [Wildcards] A cute simple line art drawing of a test_list, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast
# [Wildcards] processing: A cute simple line art drawing of a __test_list__, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast
# [Wildcards] Warning: test_list.txt missing or empty. Using "test_list" as a normal word.
# [Wildcards] A cute simple line art drawing of a test_list, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast
# [Wildcards] processing: A cute simple line art drawing of a __test_list__, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast
# [Wildcards] Warning: test_list.txt missing or empty. Using "test_list" as a normal word.
# [Wildcards] A cute simple line art drawing of a test_list, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast
# [Wildcards] processing: A cute simple line art drawing of a __test_list__, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast
# [Wildcards] Warning: test_list.txt missing or empty. Using "test_list" as a normal word.
# [Wildcards] A cute simple line art drawing of a test_list, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] A cute simple line art drawing of a test_list, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast, very detailed, sharp focus, bright colors, inspired, innocent, elegant, deep light, epic, clear, artistic, highly original, attractive, creative, beautiful, breathtaking, lovely, amazing, surreal, pretty
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] A cute simple line art drawing of a test_list, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast, highly detailed, sharp focus, great composition, innocent, dynamic light, aesthetic, very inspirational, bright color, clear, artistic, professional, winning, new, best, creative, positive, joyful, unique
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] A cute simple line art drawing of a test_list, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast, sharp focus, infinite complex, highly detailed, very nice, focused, innocent, pure, light color, inspired, rich deep colors, cinematic, vivid perfect, clear, artistic, original, depicted, fine detail
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] A cute simple line art drawing of a test_list, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast, extremely detailed, sharp focus, great composition, dynamic light, cinematic, highly detail, elegant, innocent, rich, winning, color, inspired, brave, vibrant, epic, stunning, creative, beautiful, amazing
# [Fooocus] Preparing Fooocus text #5 ...
# [Prompt Expansion] A cute simple line art drawing of a test_list, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast, great composition, dynamic light, cinematic, highly detailed, sharp focus, inspired, innocent, fine detail, clear aesthetic, pretty, attractive, creative, ambient color, illuminated, loving, caring, generous, dramatic
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Image processing ...
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.67 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.50 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 68.47 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.41 seconds
# 100% 30/30 [00:26<00:00,  1.14it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 30.51 seconds
# [Fooocus] Preparing task 2/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.63 seconds
# 100% 30/30 [00:26<00:00,  1.13it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 29.70 seconds
# [Fooocus] Preparing task 3/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.64 seconds
# 100% 30/30 [00:27<00:00,  1.11it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.32 seconds
# [Fooocus] Saving image 3/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 30.47 seconds
# [Fooocus] Preparing task 4/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.60 seconds
# 100% 30/30 [00:27<00:00,  1.09it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 4/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 30.90 seconds
# [Fooocus] Preparing task 5/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.62 seconds
# 100% 30/30 [00:28<00:00,  1.06it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 5/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 31.63 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 153.20 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 221.74 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.82 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 6703711673303081029
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/control-lora-canny-rank128.safetensors" to /content/Fooocus/models/controlnet/control-lora-canny-rank128.safetensors
#
# 100% 377M/377M [00:44<00:00, 8.87MB/s]
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] A cute simple line art drawing of a Lion, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast, highly detailed, sharp focus, great composition, dynamic light, cinematic, crisp, aesthetic, very inspirational, colorful, deep vibrant colors, inspired, rich bright color, beautiful scenic whole majestic full massive breathtaking epic amazing awesome elegant
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] A cute simple line art drawing of a Lion, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast, sharp focus, elegant, highly detailed, deep vibrant colors, epic composition, joyful, cinematic, full detail, lovely, pretty, professional, singular, innocent, artistic, stunning, inspired, thought, iconic, shiny
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] A cute simple line art drawing of a Lion, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast, great composition, dynamic dramatic cinematic colors, aesthetic, very inspirational, bright color, clear focus, highly detailed, advanced, professional, winning, creative, positive, cheerful, attractive, artistic, varied, vibrant, beautiful
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] A cute simple line art drawing of a Lion, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast, attractive, great composition, sharp focus, intricate, elegant, professional color, highly detailed, innocent, saturated colors, beautiful, light novel, aesthetic, fine, very inspirational, colorful, dramatic artistic, thought original, enhanced
# [Fooocus] Preparing Fooocus text #5 ...
# [Prompt Expansion] A cute simple line art drawing of a Lion, white background, thick lines, coloring book style, vector style, minimal, no shading, high contrast, dynamic composition, colorful, detailed, cinematic, professional, elegant, very inspirational, attractive, draped, passionate, extremely aesthetic, full color, cool, dramatic, intricate, highly detail, sharp focus, fine, complex composed
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.19 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Image processing ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 49.75 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.27 seconds
# 100% 30/30 [00:29<00:00,  1.02it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# [Fooocus] Saving image 1/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 33.81 seconds
# [Fooocus] Preparing task 2/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.63 seconds
# 100% 30/30 [00:30<00:00,  1.01s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# [Fooocus] Saving image 2/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 34.02 seconds
# [Fooocus] Preparing task 3/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.63 seconds
# 100% 30/30 [00:30<00:00,  1.03s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.32 seconds
# [Fooocus] Saving image 3/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 34.77 seconds
# [Fooocus] Preparing task 4/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.62 seconds
# 100% 30/30 [00:31<00:00,  1.06s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.37 seconds
# [Fooocus] Saving image 4/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 36.18 seconds
# [Fooocus] Preparing task 5/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.61 seconds
# 100% 30/30 [00:32<00:00,  1.08s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# [Fooocus] Saving image 5/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 36.43 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 175.22 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 225.10 seconds
# [Fooocus Model Management] Moving model(s) has taken 1.03 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1927750479171362139
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] A cute simple line art drawing of a Lion, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading, sharp focus, intricate, detailed, color spread, clear, very artistic, innocent, enhanced, symmetry, romantic, novel, fine detail, full bright colors, professional
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] A cute simple line art drawing of a Lion, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading, professional, cinematic, artistic, pure, positive, attractive, detailed, stunning, intricate detail, focused, great composition, clear, beautiful, elegant, perfect, romantic
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] A cute simple line art drawing of a Lion, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading, sharp focus, intricate, detailed, very gentle color, innocent, warm light, cinematic, borne, infinite, intriguing, highly educated, deep vibrant colors, artistic, pretty
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] A cute simple line art drawing of a Lion, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading, sharp focus, handsome, detailed, highly saturated colors, aesthetic, dynamic, cinematic, intricate, innocent, elegant, sublime, crisp, very inspirational, bright color, illuminated
# [Fooocus] Preparing Fooocus text #5 ...
# [Prompt Expansion] A cute simple line art drawing of a Lion, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading, sharp focus, winning, cinematic, highly detailed, formal, professional, artistic, varied color, inspired, iconic, illuminated, best, romantic, light, atmosphere, calm
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Image processing ...
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.20 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.65 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 5.37 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.67 seconds
# 100% 30/30 [00:25<00:00,  1.16it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 29.01 seconds
# [Fooocus] Preparing task 2/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.66 seconds
# 100% 30/30 [00:26<00:00,  1.13it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 2/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 29.86 seconds
# [Fooocus] Preparing task 3/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.62 seconds
# 100% 30/30 [00:27<00:00,  1.11it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 3/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 30.48 seconds
# [Fooocus] Preparing task 4/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.65 seconds
# 100% 30/30 [00:27<00:00,  1.08it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 4/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 30.90 seconds
# [Fooocus] Preparing task 5/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.62 seconds
# 100% 30/30 [00:28<00:00,  1.06it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 5/5 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-01-29/log.html
# Generating and saving time: 31.61 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 151.86 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 157.29 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.97 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 9125029895935661848
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Wildcards] processing: A cute simple line art drawing of a __test_list__, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading
# [Wildcards] Warning: test_list.txt missing or empty. Using "test_list" as a normal word.
# [Wildcards] A cute simple line art drawing of a test_list, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading
# [Wildcards] processing: A cute simple line art drawing of a __test_list__, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading
# [Wildcards] Warning: test_list.txt missing or empty. Using "test_list" as a normal word.
# [Wildcards] A cute simple line art drawing of a test_list, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading
# [Wildcards] processing: A cute simple line art drawing of a __test_list__, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading
# [Wildcards] Warning: test_list.txt missing or empty. Using "test_list" as a normal word.
# [Wildcards] A cute simple line art drawing of a test_list, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading
# [Wildcards] processing: A cute simple line art drawing of a __test_list__, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading
# [Wildcards] Warning: test_list.txt missing or empty. Using "test_list" as a normal word.
# [Wildcards] A cute simple line art drawing of a test_list, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading
# [Wildcards] processing: A cute simple line art drawing of a __test_list__, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading
# [Wildcards] Warning: test_list.txt missing or empty. Using "test_list" as a normal word.
# [Wildcards] A cute simple line art drawing of a test_list, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] A cute simple line art drawing of a test_list, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading, sharp focus, highly detailed, cinematic color, polished, complex, very inspirational, extremely attractive, illustrious, modern, rich, fine detail, clear, artistic
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] A cute simple line art drawing of a test_list, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading, sharp focus, highly detailed, singular focused, professional artistic, innocent, naive, iconic, polished, beautiful, epic, stunning, illuminated, incredible, cinematic
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] A cute simple line art drawing of a test_list, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading, sharp focus, cool, professional, highly detailed, cinematic color quality, dramatic light, beautiful, elegant, deep colors, epic, very artistic, fine detail
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] A cute simple line art drawing of a test_list, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading, sharp focus, detailed, innocent, sublime, dramatic cinematic color, extremely saturated colors, perfect composition, beautiful full, stunning intricate detail, creative, positive, cheerful
# [Fooocus] Preparing Fooocus text #5 ...
# [Prompt Expansion] A cute simple line art drawing of a test_list, coloring book style, thick clean lines, minimalist, white background, monochrome, greyscale, high contrast, 2d vector, no shading, sharp focus, highly detailed, cinematic color, dramatic dynamic light, professional still, colorful, very inspirational, beautiful, bright, perfect, illuminated, real, deep
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Image processing ...
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.18 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.44 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 5.61 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/5 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.68 seconds
#  87% 26/30 [00:23<00:03,  1.12it/s]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 23.98 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 29.60 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.80 seconds
